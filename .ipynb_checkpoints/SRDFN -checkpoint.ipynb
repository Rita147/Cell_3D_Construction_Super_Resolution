# %% [markdown]
# # Computer Vision Project : Enhancing Nucleus Segmentation and 3D Reconstruction Using Super-Resolution

# %% [markdown]
# ## Group Members:
# ### Rita Sulaiman – Student ID: 2210765051
# ### Zeynep Yıldız – Student ID: 2210765033
# ### Zharasbek Bimagambetov – Student ID: 2210356185

# %% [markdown]
# ### Imports

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch

# Kullanılmayan bellekleri temizle
torch.cuda.empty_cache()

# Zorla kullanılmayan memory'yi bırak
torch.cuda.ipc_collect()

print("GPU belleği temizlendi.")
# Out:
# GPU belleği temizlendi.

# %% [markdown]
# ### Preprocessing and Image Display

# %%
# ==============================================
# ✅ SRDFN (Super-Resolution Dense Feature Network)
# For Histopathology Image Super-Resolution
# ==============================================

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.transforms import functional as TF
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from skimage.metrics import peak_signal_noise_ratio, structural_similarity

# %%
# -----------------------------
# 🔹 SRDFN Model
# -----------------------------
class SRDFN(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, num_features=64):
        super(SRDFN, self).__init__()

        self.initial = nn.Conv2d(in_channels, num_features, kernel_size=3, padding=1)

        self.dense_block = nn.Sequential(
            nn.Conv2d(num_features, num_features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(num_features, num_features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(num_features, num_features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        self.reconstruction = nn.Sequential(
            nn.Conv2d(num_features, num_features * 4, kernel_size=3, padding=1),
            nn.PixelShuffle(2),
            nn.ReLU(inplace=True),
            nn.Conv2d(num_features, out_channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        x = self.initial(x)
        x = self.dense_block(x)
        x = self.reconstruction(x)
        return x

# %%
# -----------------------------
# 🔹 Dataset Class
# -----------------------------
class HistopathologySRDataset(Dataset):
    def __init__(self, image_dir, transform_hr, transform_lr):
        self.image_dir = image_dir
        self.image_filenames = [f for f in os.listdir(image_dir) if f.endswith('.png') or f.endswith('.jpg')]
        self.transform_hr = transform_hr
        self.transform_lr = transform_lr

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_filenames[idx])
        img = Image.open(img_path).convert('RGB')
        hr = self.transform_hr(img)
        lr = self.transform_lr(img)
        return lr, hr

# %%
# -----------------------------
# 🔹 Transforms
# -----------------------------
transform_hr = transforms.Compose([
    transforms.Resize((512, 512)),
    transforms.ToTensor()
])

transform_lr = transforms.Compose([
    transforms.Resize((256, 256)),  # düşük çözünürlük girişi
    transforms.ToTensor()
])

# %%
import torchvision.models as models
import torch.nn.functional as F
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# VGG modelini yükle
vgg = models.vgg19(pretrained=True).features[:16].eval().to(device)
for param in vgg.parameters():
    param.requires_grad = False

# Perceptual loss fonksiyonu
def perceptual_loss(sr, hr):
    return F.mse_loss(vgg(sr), vgg(hr))
# Out:
# C:\Users\Zeynep\anaconda3\envs\cmp_torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Zeynep\anaconda3\envs\cmp_torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# -----------------------------
# 🔹 Training Setup
# -----------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SRDFN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

dataset = HistopathologySRDataset("all tissue img", transform_hr, transform_lr)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
# -----------------------------
# 🔹 Training Loop
# -----------------------------
num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for lr_imgs, hr_imgs in tqdm(dataloader):
        lr_imgs, hr_imgs = lr_imgs.to(device), hr_imgs.to(device)

        sr_imgs = model(lr_imgs)
        loss = criterion(sr_imgs, hr_imgs) + 0.01 * perceptual_loss(sr_imgs, hr_imgs)


        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(dataloader):.4f}")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:11<00:00,  1.27it/s]
# Epoch 1/50, Loss: 0.0323
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:18<00:00,  1.20it/s]
# Epoch 2/50, Loss: 0.0081
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:20<00:00,  1.19it/s]
# Epoch 3/50, Loss: 0.0046
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:21<00:00,  1.18it/s]
# Epoch 4/50, Loss: 0.0031
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:25<00:00,  1.15it/s]
# Epoch 5/50, Loss: 0.0022
# 100%|████████████████████████████████████████████████████████████████████████████████| 167/167 [02:21<00:00,  1.18it/s]
# Epoch 6/50, Loss: 0.0017
# ...

# %%
# -----------------------------
# 🔹 Evaluation Visualization
# -----------------------------
def evaluate_srdfn(model, dataset, device, index=0):
    model.eval()
    with torch.no_grad():
        lr, hr = dataset[index]
        lr_tensor = lr.unsqueeze(0).to(device)
        sr_tensor = model(lr_tensor).cpu().squeeze(0).clamp(0, 1)

        # PSNR & SSIM
        sr_np = sr_tensor.permute(1, 2, 0).numpy()
        hr_np = hr.permute(1, 2, 0).numpy()
        psnr = peak_signal_noise_ratio(hr_np, sr_np, data_range=1.0)
        ssim = structural_similarity(hr_np, sr_np, channel_axis=2, data_range=1.0)


        lr_img = TF.to_pil_image(lr)
        sr_img = TF.to_pil_image(sr_tensor)
        hr_img = TF.to_pil_image(hr)
        print("Görüntü boyutu:", sr_img.size)
        print(f" PSNR: {psnr:.2f} dB")
        print(f" SSIM: {ssim:.4f}")
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 3, 1)
        plt.title("Low-Res")
        plt.imshow(lr_img)
        plt.axis("off")

        plt.subplot(1, 3, 2)
        plt.title(f"SR Output")
        plt.imshow(sr_img)
        plt.axis("off")

        plt.subplot(1, 3, 3)
        plt.title("High-Res (GT)")
        plt.imshow(hr_img)
        plt.axis("off")

        plt.tight_layout()
        plt.show()

# %%
# -----------------------------
# 🔹 Run evaluation
# -----------------------------
evaluate_srdfn(model, dataset, device, index=0)
# Out:
# Görüntü boyutu: (512, 512)
#  PSNR: 35.62 dB
#  SSIM: 0.8692

# %%
torch.save(model, "srdfn_model.pth")
